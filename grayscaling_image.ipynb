# %%
#importing libraries

import cv2
import matplotlib.pyplot as plt

# %%
# define  our imshow function
def imshow(title='image',image=None,size=10):
  w,h=image.shape[0],image.shape[1]
  aspect_ratio=w/h
  plt.figure(figsize=(size*aspect_ratio,size))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()

# %%
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# !unzip -qq images.zip
# Out:
# --2024-12-03 06:14:35--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 3.5.244.176, 3.5.245.179, 3.5.244.113, ...
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|3.5.244.176|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-12-03 06:14:35 ERROR 404: Not Found.
#
# unzip:  cannot find or open images.zip, images.zip.zip or images.zip.ZIP.

# %%
image= cv2.imread('/content/IMG_20230827_071038424_HDR.jpg')
imshow('dogs',image)

# %%
image.shape[:2]
def imshow(title='image',image=None,size=10):
  w,h=image.shape[0],image.shape[1]
  aspect_ratio=w/h
  plt.figure(figsize=(size*aspect_ratio,size))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()
imshow(
    'dogs',
    image
)

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
imshow('converted to gray image',gray_image)
